# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r'C:\Users\shabb\Downloads\Sirrji.xlsx')
data.head()
# Out:
#              Player       Span Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0  DG Bradman (AUS)  1928-1948  52    80  10  6996   334  99.94  9800+  58.60
# 1    HC Brook (ENG)  2022-2023  12    20   1  1181   186  62.15   1287  91.76
# 2    AC Voges (AUS)  2015-2016  20    31   7  1485  269*  61.87   2667  55.68
# 3   RG Pollock (SA)  1963-1970  23    41   4  2256   274  60.97  1707+  54.48
# 4   GA Headley (WI)  1930-1954  22    40   4  2190  270*  60.83   416+  56.00
#
#    100  50  0   4s  6s
# 0   29  13  7  626   6
# 1    4   7  1  141  23
# 2    5   4  2  186   5
# 3    7  11  1  246  11
# 4   10   5  2  104   1

# %%
data.shape
# Out:
# (62, 15)

# %%
data.describe()
# Out:
#              Inns         NO          Runs        Ave        100         50  \
# count   62.000000  62.000000     62.000000  62.000000  62.000000  62.000000
# mean   135.677419  14.096774   6422.467742  53.674032  19.322581  28.596774
# std     86.489035  11.155694   4013.489822   7.198296  12.332516  18.626140
# min     20.000000   1.000000    990.000000  48.000000   1.000000   3.000000
# 25%     51.500000   5.250000   2379.000000  49.510000   7.250000  11.500000
# 50%    134.500000  12.000000   6520.500000  51.735000  19.500000  28.500000
# 75%    196.250000  19.000000   8844.000000  56.345000  29.000000  42.500000
# max    329.000000  49.000000  15921.000000  99.940000  51.000000  68.000000
#
#                0           4s         6s
# count  62.000000    62.000000  62.000000
# mean    7.806452   652.774194  27.338710
# std     5.536285   522.549156  27.157672
# min     1.000000    37.000000   0.000000
# 25%     3.000000   147.250000   5.250000
# ...

# %%
data.describe(include='object')
# Out:
#                   Player       Span Mat    HS  BF  SR
# count                 62         62  62    62  62  62
# unique                62         59  52    58  60  60
# top     DG Bradman (AUS)  1948-1963  20  144*   -   -
# freq                   1          2   4     2   3   3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     object
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     object
#  7   Ave     62 non-null     float64
#  8   BF      62 non-null     object
#  9   SR      62 non-null     object
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     int64
#  13  4s      62 non-null     int64
#  14  6s      62 non-null     int64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 7.4+ KB

# %%
data.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
data.head()
# Out:
#              Player       Span Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0  DG Bradman (AUS)  1928-1948  52    80  10  6996   334  99.94  9800+  58.60
# 1    HC Brook (ENG)  2022-2023  12    20   1  1181   186  62.15   1287  91.76
# 2    AC Voges (AUS)  2015-2016  20    31   7  1485  269*  61.87   2667  55.68
# 3   RG Pollock (SA)  1963-1970  23    41   4  2256   274  60.97  1707+  54.48
# 4   GA Headley (WI)  1930-1954  22    40   4  2190  270*  60.83   416+  56.00
#
#    100  50  0   4s  6s
# 0   29  13  7  626   6
# 1    4   7  1  141  23
# 2    5   4  2  186   5
# 3    7  11  1  246  11
# 4   10   5  2  104   1

# %%
data['Start_year']=data['Span'].str.split('-').str[0]
data['End_year']=data['Span'].str.split('-').str[1]

# %%
data['Player_name']=data['Player'].str.split('(').str[0]

# %%
data['Country']=data['Player'].str.split('(').str[1].str.split(')').str[0]

# %%
data.drop(['Player','Span'],axis=1, inplace=True)

# %%
data[['Start_year','End_year']]=data[['Start_year','End_year']].astype('int')

# %%
data['HS']=data['HS'].astype('int')

# %%
data["HS"]=data["HS"].replace("[*]","", regex=True)

# %%
 data['BF']= data['BF'].astype('int')

# %%
data['BF']=data['BF'].replace('[+]','', regex=True)
data['BF']=data['BF'].replace('[-]','', regex=True)
data['BF']=data['BF'].replace('','0', regex=True)

# %%
data['Career_lenght']=data['End_year']-data['Start_year']

# %%
data['Mat']=data['Mat'].astype('int')

# %%
data['Mat']=data['Mat'].replace('[*]','', regex=True)

# %%
data[data['SR']==data['SR'].max()]
# Out:
#    Mat  Inns  NO  Runs   HS    Ave    BF     SR  100  50  0   4s  6s  \
# 1   12    20   1  1181  186  62.15  1287  91.76    4   7  1  141  23
#
#    Start_year  End_year Player_name Country  Career_lenght
# 1        2022      2023   HC Brook      ENG              1

# %%
data[data['100']==data['100'].max()]
# Out:
#     Mat  Inns  NO   Runs   HS    Ave     BF     SR  100  50   0    4s  6s  \
# 23  200   329  33  15921  248  53.78  29437  54.04   51  68  14  2058  69
#
#     Start_year  End_year    Player_name Country  Career_lenght
# 23        1989      2013  SR Tendulkar      IND             24

# %%
data[data['Runs']==data['Runs'].max()]
# Out:
#     Mat  Inns  NO   Runs   HS    Ave     BF     SR  100  50   0    4s  6s  \
# 23  200   329  33  15921  248  53.78  29437  54.04   51  68  14  2058  69
#
#     Start_year  End_year    Player_name Country  Career_lenght
# 23        1989      2013  SR Tendulkar      IND             24

# %%
data[data['Inns']==data['Inns'].max()]
# Out:
#     Mat  Inns  NO   Runs   HS    Ave     BF     SR  100  50   0    4s  6s  \
# 23  200   329  33  15921  248  53.78  29437  54.04   51  68  14  2058  69
#
#     Start_year  End_year    Player_name Country  Career_lenght
# 23        1989      2013  SR Tendulkar      IND             24

# %%
data['Country'].replace('ICC/','',regex=True)
# Out:
# 0     AUS
# 1     ENG
# 2     AUS
# 3      SA
# 4      WI
#      ...
# 57    AUS
# 58     SA
# 59    AUS
# 60    AUS
# 61    ENG
# Name: Country, Length: 62, dtype: object

# %%
data.head()
# Out:
#    Mat  Inns  NO  Runs   HS    Ave    BF     SR  100  50  0   4s  6s  \
# 0   52    80  10  6996  334  99.94  9800  58.60   29  13  7  626   6
# 1   12    20   1  1181  186  62.15  1287  91.76    4   7  1  141  23
# 2   20    31   7  1485  269  61.87  2667  55.68    5   4  2  186   5
# 3   23    41   4  2256  274  60.97  1707  54.48    7  11  1  246  11
# 4   22    40   4  2190  270  60.83   416  56.00   10   5  2  104   1
#
#    Start_year  End_year  Player_name Country  Career_lenght
# 0        1928      1948  DG Bradman      AUS             20
# 1        2022      2023    HC Brook      ENG              1
# 2        2015      2016    AC Voges      AUS              1
# 3        1963      1970  RG Pollock       SA              7
# 4        1930      1954  GA Headley       WI             24

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Player_name'].duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Mat            62 non-null     int32
#  1   Inns           62 non-null     int64
#  2   NO             62 non-null     int64
#  3   Runs           62 non-null     int64
#  4   HS             62 non-null     int32
#  5   Ave            62 non-null     float64
#  6   BF             62 non-null     int32
#  7   SR             62 non-null     float64
#  8   100            62 non-null     int64
#  9   50             62 non-null     int64
#  10  0              62 non-null     int64
#  11  4s             62 non-null     int64
#  12  6s             62 non-null     int64
#  13  Start_year     62 non-null     int32
#  14  End_year       62 non-null     int32
#  15  Player_name    62 non-null     object
#  16  Country        62 non-null     object
#  17  Career_lenght  62 non-null     int32
# ...

# %%
data['SR']=data['SR'].astype('float')

# %%
data['SR']=data['SR'].replace('[-]','', regex=True)
data['SR']=data['SR'].replace('',50.0, regex=True)

# %%
data[data['SR']==0]
# Out:
# Empty DataFrame
# Columns: [Mat, Inns, NO, Runs, HS, Ave, BF, SR, 100, 50, 0, 4s, 6s, Start_year, End_year, Player_name, Country, Career_lenght]
# Index: []

# %%
data.columns
# Out:
# Index(['Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0',
#        '4s', '6s', 'Start_year', 'End_year', 'Player_name', 'Country',
#        'Career_lenght'],
#       dtype='object')

# %%
data.columns=[[ 'Player_name','Matches', 'Innings', 'NOt_out', 'Runs', 'Highest_Score', 'Average', 'Balls_faced', 'Strike_Rate', 'Century', 'Century_half', '0',
       '4s', '6s', 'Start_year', 'End_year', 'Country',
       'Career_lenght']]

# %%
data
# Out:
#    Player_name Matches Innings NOt_out Runs Highest_Score Average Balls_faced  \
# 0           52      80      10    6996  334         99.94    9800       58.60
# 1           12      20       1    1181  186         62.15    1287       91.76
# 2           20      31       7    1485  269         61.87    2667       55.68
# 3           23      41       4    2256  274         60.97    1707       54.48
# 4           22      40       4    2190  270         60.83     416       56.00
# ..         ...     ...     ...     ...  ...           ...     ...         ...
# 57          74     125      14    5357  250         48.26    8662       49.16
# 58         117     205      13    9265  277         48.25   15525       59.67
# 59          29      48       4    2122  266         48.22    3118       44.77
# 60          39      62       5    2748  232         48.21    3217       60.02
# 61          22      33       6    1296  127         48.00    2110       25.59
#
# ...

# %%
data.to_excel('cleandata.xlsx', index=False)
